# %%
##################### PHASE 1 ########################
#STEP 1: Environment setup and data loading 
#Flooding Project: Durban (South Africa) vs Lagos (Nigeria)

## Purpose
#This notebook prepares all datasets used throughout the comparative flood 
#risk assessment of Lagos (Nigeria) and Durban (South Africa). 
#The objective is to import raw datasets, standardise formats.

## Research Context
#Reliable data preparation is a prerequisite for reproducible scientific analysis. 
#Because this study integrates multiple data sources, including climate records,
#disaster databases, demographic indicators, and spatial datasets, a consistent preprocessing 
#workflow is required before statistical modelling and spatial analysis.

##Input Data
#This notebook processes datasets including:

#Annual precipitation records
#Annual mean surface air temperature
#Population and urbanisation indicators
#EM-DAT flood disaster records
#Built surface raster datasets

##Methods
#The following preprocessing steps are performed:
#Import datasets
##Inspect data structure





#Import libraries
import pandas as pd #handles tables
import numpy as np #Like base R matrix math
import matplotlib.pyplot as plt #Base plotting engine
import seaborn as sns #prettier charts on top of matplotlib
import os #For working with file paths and folders

#Set seaborn style (equivalent to theme_minimal() in ggplot2)
sns.set_theme(style="whitegrid", palette="muted")

print("All libraries loaded successfully!")

# %%
#Define file paths 
#In R I might use setwd() or here::here()
#In Python, os.path.join() builds file paths that work on any OS

#Base folder - change this to match where my  project lives
BASE_DIR = r"C:\Users\drsih\Desktop\profile\flooding_project"

#Sub-folders (raw data)
CLIMATE_DIR   = os.path.join(BASE_DIR, "data", "raw", "climate")
EMDAT_DIR     = os.path.join(BASE_DIR, "data", "raw", "emdat")
URBAN_DIR     = os.path.join(BASE_DIR, "data", "raw", "urban")
LULC_DIR      = os.path.join(BASE_DIR, "data", "raw", "lulc")
TOPO_DIR      = os.path.join(BASE_DIR, "data", "raw", "topography")

# %%
#Output folder for saving charts
OUTPUT_DIR    = os.path.join(BASE_DIR, "data", "outputs", "figures")
os.makedirs(OUTPUT_DIR, exist_ok=True)  #Create folder if it doesn't exist
#R equivalent: dir.create(OUTPUT_DIR, recursive = TRUE)

print(f"Base directory set to: {BASE_DIR}")

# %%
##Summary

## Main Outcomes

- Imported all datasets successfully.
- Cleaned inconsistent records and variable names.
- Standardised data formats across all sources.
- Generated analysis-ready datasets for climate, disaster and urbanisation analyses.

## Limitations

- Some datasets required national-level proxies because city-level observations were unavailable.
- Data completeness varies across sources and years.

## Next Notebook

➡ **02_climate_trend_analysis.ipynb**

The next notebook investigates long-term climate trends using precipitation and temperature records to determine whether climatic changes are associated with increasing flood occurrence.
